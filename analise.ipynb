# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.offline import plot, iplot, init_notebook_mode
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import r2_score, mean_squared_error
import missingno as msno

# %%
data = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
y = data['Survived']

# %%
data.shape
# Out:
# (891, 12)

# %%
data.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
data.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
X = data.drop(['PassengerId','Survived', 'Name', 'Ticket', 'Cabin'], axis = 1 )

# %%
X.head(10)
# Out:
#    Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0       3    male  22.0      1      0   7.2500        S
# 1       1  female  38.0      1      0  71.2833        C
# 2       3  female  26.0      0      0   7.9250        S
# 3       1  female  35.0      1      0  53.1000        S
# 4       3    male  35.0      0      0   8.0500        S
# 5       3    male   NaN      0      0   8.4583        Q
# 6       1    male  54.0      0      0  51.8625        S
# 7       3    male   2.0      3      1  21.0750        S
# 8       3  female  27.0      0      2  11.1333        S
# 9       2  female  14.0      1      0  30.0708        C

# %%
X.isna().sum(), X.shape
# Out:
# (Pclass        0
#  Sex           0
#  Age         177
#  SibSp         0
#  Parch         0
#  Fare          0
#  Embarked      2
#  dtype: int64,
#  (891, 7))

# %%
X.describe()
# Out:
#            Pclass         Age       SibSp       Parch        Fare
# count  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.836071   14.526497    1.102743    0.806057   49.693429
# min      1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      3.000000   38.000000    1.000000    0.000000   31.000000
# max      3.000000   80.000000    8.000000    6.000000  512.329200

# %%
v = {}
ind = 0
for ind in range(X['Fare'].shape[0]):
    if X['Fare'].iloc[ind] == 0:
        v.update({ind : X['Fare'].iloc[ind]})

print(v.items())
# Out:
# dict_items([(179, 0.0), (263, 0.0), (271, 0.0), (277, 0.0), (302, 0.0), (413, 0.0), (466, 0.0), (481, 0.0), (597, 0.0), (633, 0.0), (674, 0.0), (732, 0.0), (806, 0.0), (815, 0.0), (822, 0.0)])

# %%
test['Fare'].shape[0]
# Out:
# 418

# %%
vt = {}
indt = 0
for indt in range(test['Fare'].shape[0]):
    if test['Fare'].iloc[indt] == 0:
        vt.update({indt : test['Fare'].iloc[indt]})

print(vt.items())
# Out:
# dict_items([(266, 0.0), (372, 0.0)])

# %%
indices = list(v.keys())
indices_t = list(vt.keys())

# %%
indices, indices_t
# Out:
# ([179, 263, 271, 277, 302, 413, 466, 481, 597, 633, 674, 732, 806, 815, 822],
#  [266, 372])

# %%
data.iloc[indices]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
test.iloc[indices_t]
# Out:
#      PassengerId  Pclass                                   Name   Sex   Age  \
# 266         1158       1  Chisholm, Mr. Roderick Robert Crispin  male   NaN
# 372         1264       1                Ismay, Mr. Joseph Bruce  male  49.0
#
#      SibSp  Parch  Ticket  Fare        Cabin Embarked
# 266      0      0  112051   0.0          NaN        S
# 372      0      0  112058   0.0  B52 B54 B56        S
